# %% [markdown]
# <a href="https://colab.research.google.com/github/kanokrada-dot/My-Team/blob/kanokrada-dot-patch-1/a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
services_menu = {
    1: {"name":  "เติมลมยาง","price": "20"},
    2: {"name":  "ปะยาง","price": "70"},
    3: {"name":  "เปลี่ยนยาง","price": "500"},
    4: {"name":  "เปลี่ยนน้ำมันเครื่อง","price": "220"}
}
staff_list = {
    101 : {"สมชัย (ปะยาง/เติมลมยาง)"},
    102 : {"ชาส้ม (เปลี่ยนยาง)"},
    103 : {"มะลิ (เปลี่ยนน้ำมันเครื่อง)"}
}
jods_database = []
